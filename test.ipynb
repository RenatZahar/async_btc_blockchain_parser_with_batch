# %% [markdown]
# асинхронный срипт
# * превратить многопточный в однопточный
# * добавить асинхронность
# * добавить батчинг
# * добавить хэш блока в запросы по транзакции

# %%
import os
print(os.getcwd())

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.precision', 2)
pd.set_option('display.expand_frame_repr', False)


# Загрузка данных из NumPy массива
dir = 'I:\\Traider_bot\\обработка данных\\parsing\\data\\'
name = 'block_data_754135-754210.parquet'
data = pd.read_parquet(dir+name)

# Преобразование NumPy массива в DataFrame
df = pd.DataFrame(data)

# Вывод первых нескольких строк DataFrame для проверки
pd.set_option('display.max_colwidth', None)
# print(df.loc[df['Amount']]>0)
# print(df.sample(10))
print(df.sample(10))
# print(df[(df['Transaction_id'] == '5328eb2e915ed0f18ff8d568f7c7493297bf3b0a5fb8a3546710bc5c2628fca2')])
# Out:
#                                                           Transaction_id                                   Wallet_id  Btc_block_time_price  Block_time  Block_height                                                        Block_hash    n    Amount  Transactions_Count
# 299190  924bde4a6bf50ca3b33d6383ec332331d8f2384894b70c69ce0bbca69c86fb0b          3K9SALiajQXdrexwip6apKCZ38mG5jtrZ8              20039.36  1663224057        754176  0000000000000000000055541e915a82af0dda476fba08e5f40ac0cbc79d6197    5 -7.15e-03                   1
# 293818  bbe006a498edba25e2ac1ecaecc0998b77ca3087f373ab9785e31614582d19cd          3HVBP99xYkoUzHyidZ7CjqCTCa7NQKiQSZ              20073.02  1663223798        754175  0000000000000000000792ad8eb8a7123c88a5e89b2fed178e069fd72c40d26b    0 -4.60e-03                   1
# ...

# %%
tx = df.sample(1)
tx_id = tx['Transaction_id'].iloc[0]
df[df['Transaction_id'] == tx_id]
# Out:
#          index                                                    Transaction_id                                   Wallet_id  Btc_block_time_price  Block_time  Block_height                                                        Block_hash  n       Amount
# 306665  105899  5a1b12fa3ca93d4fc550bb10cf1d5ea0619c725867df087245e5d759641968a4  bc1qg4wj58f7tl6h2f28ppzgmqh6l3g8ee9gknl3ts              19001.92  1663756736        755079  00000000000000000007ca5d2bb59e307939ee8c978702e3ab908a718210ff45  0  -0.02477000
# 306666  105898  5a1b12fa3ca93d4fc550bb10cf1d5ea0619c725867df087245e5d759641968a4  bc1qepzc8fzgfxj0fwen2254fsq0ztctptcgsultej              19001.92  1663756736        755079  00000000000000000007ca5d2bb59e307939ee8c978702e3ab908a718210ff45  1   0.00420882
# ...

# %%
# Out:
#         index                                                    Transaction_id                           Wallet_id  Btc_block_time_price  Block_time  Block_height                                                        Block_hash    n      Amount
# 23425  188074  981194fb3ee32520329e72e55f7516684d4c09d7586f6f41e093958d2d89c17b  1HEZXkzNUCoXh6xA4m2fbggYJvLE8UegHJ               19007.5  1663734127        755032  0000000000000000000066c0742c6e711814ad2f5f3625f65530387e1d61325e  171  0.00327648
# 23426  188072  981194fb3ee32520329e72e55f7516684d4c09d7586f6f41e093958d2d89c17b  1GyTzt3Vmxbtayg7WP1fn2zu2i4M17kfqH               19007.5  1663734127        755032  0000000000000000000066c0742c6e711814ad2f5f3625f65530387e1d61325e  270  0.01194137
# 23456  188081  981194fb3ee32520329e72e55f7516684d4c09d7586f6f41e093958d2d89c17b  1HuXGtmkw9nQCmAB9Kd1T7pUw24PCGzdYh               19007.5  1663734127        755032  0000000000000000000066c0742c6e711814ad2f5f3625f65530387e1d61325e  216  0.00231240
# ...

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.precision', 2)
pd.set_option('display.expand_frame_repr', False)
# Загрузка данных из NumPy массива
dir = 'I:\\Traider_bot\\обработка данных\\parsing\\data\\'
name = 'block_data_740098-740098.parquet'
data = pd.read_parquet(dir+name)
# обработка данных\parsing\data\block_data_740000-740004.parquet
# Преобразование NumPy массива в DataFrame
# I:\Traider_bot\обработка данных\parsing\data\block_data_740005-740009.parquet
# Вывод первых нескольких строк DataFrame для проверки
pd.set_option('display.max_colwidth', None)
# print(df.loc[df['Amount']]>0)
data[data['Amount'] > 0]
# Out:
# Empty DataFrame
# Columns: [Transaction_id, Wallet_id, Btc_block_time_price, Block_time, Block_height, Block_hash, n, Amount, Transactions_Count]
# Index: []

# %%
from bitcoinrpc.authproxy import AuthServiceProxy, JSONRPCException
import pprint as pp
rpc_url = "http://yourusername:yourpassword@localhost:8332"
rpc_connection = AuthServiceProxy(rpc_url)
blockid = '0000000000000000000885a95ce35eccbd62bb7f4eae638ca9a6b683b58ecb51'
tx_details = rpc_connection.getblock(blockid)
pp.pprint(tx_details)
# Out:
# {'bits': '1709a7af',
#  'chainwork': '0000000000000000000000000000000000000000313d9755dd9afdf6d6437d62',
#  'confirmations': 76080,
#  'difficulty': Decimal('29152798808271.88'),
#  'hash': '0000000000000000000885a95ce35eccbd62bb7f4eae638ca9a6b683b58ecb51',
#  'height': 744486,
#  'mediantime': 1657486075,
#  'merkleroot': 'c11553755bde83a80e501bbe7d1d21002a6afaedea1c9f206fe9031853dd81f1',
#  'nTx': 2,
#  'nextblockhash': '0000000000000000000644ad8173b2a62beb7460f3489a0b1fd1d9eb55c494f4',
#  'nonce': 3228976174,
#  'previousblockhash': '00000000000000000002a5f825d703299878247b93f71bf00562a8e6b8196ece',
#  'size': 811,
#  'strippedsize': 532,
#  'time': 1657488463,
#  'tx': ['c64144c134b04a26dc14a33cc44f19e4c6f852fc1f2bb1537435ab2ce4709891',
#         '8c7617594e19fb5299628abc5dac447aae5710f7b530d11940e3fb0924417d52'],
#  'version': 1073676292,
#  'versionHex': '3fff0004',
#  'weight': 2407}

# %%
from bitcoinrpc.authproxy import AuthServiceProxy, JSONRPCException

# rpc_user and rpc_password are set in the bitcoin.conf file
rpc_connection = AuthServiceProxy('http://yourusername:yourpassword@localhost:8332')
best_block_hash = rpc_connection.getbestblockhash()
print(rpc_connection.getblock(best_block_hash))

# batch support : print timestamps of blocks 0 to 99 in 2 RPC round-trips:
commands = [ [ "getblockhash", height] for height in range(100) ]
block_hashes = rpc_connection.batch_(commands)
blocks = rpc_connection.batch_([ [ "getblock", h ] for h in block_hashes ])
block_times = [ block["time"] for block in blocks ]
print(block_times)
# Out:
# {'hash': '0000000000000000000180356f561711ad15e7b9f526a1fa31825a0deeb17b5a', 'confirmations': 1, 'height': 820242, 'version': 780902400, 'versionHex': '2e8ba000', 'merkleroot': 'e635a2293bd5f9fae71af87c521c94f06aef11693a0749fc9da2c5f4ed9ca465', 'time': 1702028903, 'mediantime': 1702025978, 'nonce': 1613922388, 'bits': '17042450', 'difficulty': Decimal('67957790298897.88'), 'chainwork': '00000000000000000000000000000000000000006029144c3ee96108269f98a0', 'nTx': 3468, 'previousblockhash': '00000000000000000000ed7346829ae876324e5a4cab7b0ab476137ba374da88', 'strippedsize': 720431, 'size': 1832066, 'weight': 3993359, 'tx': ['b7693a5343c7e3c3af5ff6932327a966689d0221412978e5ad6a932cfb6dd167', '7b1add2723302e2b67d5bdfce7f3e5b28e17b30040544acd53c7d84bd4442718', '7bcd6d2ac79c4be628ceb996be3912590bd5774249ecb8e10d55ecc60b06bddd', 'a94a415a15b4518fd8ff25dccab3e2529fccc6967cfbf67a6296954a591ce782', 'fc738f84b5fdb9e59edd1dbbe397f2e6f5922b6062f77ab732e4398647328032', '04bbfdc60adcaa602ab63ba60dc33ae
# ...

# %%
from bitcoinrpc.authproxy import AuthServiceProxy, JSONRPCException
import pprint as pp
import time 
rpc_url = "http://yourusername:yourpassword@localhost:8332"
rpc_connection = AuthServiceProxy(rpc_url)
txid = '5e5af8fc157f81e5e63ca89d5ce211ef5ad470ef0631cc36be98961e07215d6f'
# blockhash_ = '00000000000000000001eb69107518912ffa128bce8c6d6be299ea9310ee69e9'
start_time = time.time()
tx_details = rpc_connection.getrawtransaction(txid, 1)#, blockhash_
end_time = time.time()
print(end_time - start_time)
pp.pprint(tx_details)
# '5328eb2e915ed0f18ff8d568f7c7493297bf3b0a5fb8a3546710bc5c2628fca2': {0: '5e5af8fc157f81e5e63ca89d5ce211ef5ad470ef0631cc36be98961e07215d6f'}
# Out:
# 0.003999471664428711
# {'blockhash': '000000000000000000038e295e028f421d628f44e491571b93f70959a81e4f0d',
#  'blocktime': 1664751671,
#  'confirmations': 64141,
#  'hash': '5e5af8fc157f81e5e63ca89d5ce211ef5ad470ef0631cc36be98961e07215d6f',
#  'hex': '...',
#  'locktime': 0,
#  'size': 812,
#  'time': 1664751671,
#  'txid': '5e5af8fc157f81e5e63ca89d5ce211ef5ad470ef0631cc36be98961e07215d6f',
#  'version': 2,
#  'vin': [{'scriptSig': {'asm': '3044022009510264a1ef00713813008cbe18f09228970174529c0a9cb3a58e3fc432ec7b02204abbcee1633ea51b3a59797461b4342e386d06f395c0b2edd7dad1628502372d[ALL] '
#                                '035cad35b6c854e7152922bc250c7226998caeceeae83f785d61d40845d6ebf4fa',
#                         'hex': '473044022009510264a1ef00713813008cbe18f09228970174529c0a9cb3a58e3fc432ec7b02204abbcee1633ea51b3a59797461b4342e386d06f395c0b2edd7dad1628502372d0121035cad35b6c854e7152922bc250c7226998caeceeae83f785d61d40845d6ebf4fa'},
#           'sequence': 4294967293,
# ...

# %%
from bitcoinrpc.authproxy import AuthServiceProxy, JSONRPCException
import pprint as pp
import time 
rpc_url = "http://yourusername:yourpassword@localhost:8332"
rpc_connection = AuthServiceProxy(rpc_url)
txid = '909d0e4d7f26982d8f8d0d637fc2e8fcf93dd4ee47775f95b307b05a465c4ff2'
# blockhash_ = '00000000000000000001eb69107518912ffa128bce8c6d6be299ea9310ee69e9'
start_time = time.time()
tx_details = rpc_connection.getrawtransaction(txid, 1)
end_time = time.time()
print(end_time - start_time)
pp.pprint(tx_details)
# Out:
# 0.02217388153076172
# {'blockhash': '000000000000000000047a450a48cc4d34a4621c6f7d036ff085d4012905fc58',
#  'blocktime': 1655898098,
#  'confirmations': 79190,
#  'hash': '909d0e4d7f26982d8f8d0d637fc2e8fcf93dd4ee47775f95b307b05a465c4ff2',
#  'hex': '...',
#  'locktime': 0,
#  'size': 14787,
#  'time': 1655898098,
#  'txid': '909d0e4d7f26982d8f8d0d637fc2e8fcf93dd4ee47775f95b307b05a465c4ff2',
#  'version': 2,
#  'vin': [{'scriptSig': {'asm': '304402202ca4b1a8fa0a373faf5023bcd178097a5632944834c8114162fd021975db774502206256c44ba425bae2e2a5e03c5f6db620e9dfd2bed39f30fb3e9b00b61fe57300[ALL] '
#                                '02609e20bf292397cd0c9621e31b7668674a96b73a58ae574016940ac3e4dd6660',
#                         'hex': '47304402202ca4b1a8fa0a373faf5023bcd178097a5632944834c8114162fd021975db774502206256c44ba425bae2e2a5e03c5f6db620e9dfd2bed39f30fb3e9b00b61fe57300012102609e20bf292397cd0c9621e31b7668674a96b73a58ae574016940ac3e4dd6660'},
#           'sequence': 4294967295,
# ...

# %%
0.01753067970275879
{'blockhash': '000000000000000000017114ac624d6e4bb5516876eeaa00d4387ffeaa54b091',
 'blocktime': 1663539735,
 'confirmations': 66202,
 'hash': '3ba19ef159f1bea6eb61cff7b065b2877233a632966399cf437c417fa6e00ff9',
 'hex': '...',
 'locktime': 0,
 'size': 661,
 'time': 1663539735,
 'txid': '5328eb2e915ed0f18ff8d568f7c7493297bf3b0a5fb8a3546710bc5c2628fca2',
 'version': 1,
 'vin': [{'scriptSig': {'asm': '', 'hex': ''},
          'sequence': 4294967295,
          'txid': '0da7e353acce90f57c06a26d53cc19e149d40325435600d45af7a929cc6961bc',
          'txinwitness': ['30450221008da5445f6eb87702ba32a608f7587b06f6b07d45ecf1f05df03cf42235c21a4e02203f48714aad013ab08fcc3c230dba5598331dcc57c8f310f78b66460a091d800b01',
                          '0317f8e274b78bf8359dd3372ae7acb2575049e0d1ed9609bd646bf14f777414ff'],
          'vout': 33},
         {'scriptSig': {'asm': '', 'hex': ''},
          'sequence': 4294967295,
          'txid': '09188e1c6bbd95aaf8e9e97e4dbd109b7963983514e352d197f866c27c9cabe4',
          'txinwitness': ['3044022074987635d5e0f6815448cc5a4a7b50eb660ec8f04065ce2af006fef73ad5775d02200492d77d3d0b0e15f0ad60eae9c0c7f6aae2aa0f0fe4fd0c0da782a00e7d1ac101',
                          '03ff7fa6a3eb9721f090474fe1096b71e344fb396d081e827c549e96d8aa650c88'],
          'vout': 7}],
 'vout': [{'n': 0,
           'scriptPubKey': {'address': '1QCc2SCUhioNXRfm7aUsFyJDRJqTvSXEgU',
                            'asm': 'OP_DUP OP_HASH160 '
                                   'fe7cb4ae05057869719a546390c22c61987d1034 '
                                   'OP_EQUALVERIFY OP_CHECKSIG',
                            'desc': 'addr(1QCc2SCUhioNXRfm7aUsFyJDRJqTvSXEgU)#489hn8yd',
                            'hex': '76a914fe7cb4ae05057869719a546390c22c61987d103488ac',
                            'type': 'pubkeyhash'},
           'value': Decimal('0.00945627')},

# %%
import requests
import pickle
from collections import deque
import numpy as np
from collections import OrderedDict
import os
import re
import gzip
import pprint as pp



with gzip.open('обработка данных\\parsing\\однопоточный скрипт с batch\\tx_cache.pkl.gz', 'rb') as file:
    cache = pickle.load(file)


pp.pprint(cache)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 13
#       8 import gzip
#       9 import pprint as pp
# ---> 13 with gzip.open('обработка данных\\parsing\\однопоточный скрипт с batch\\tx_cache.pkl.gz', 'rb') as file:
#      14     cache = pickle.load(file)
#      17 pp.pprint(cache)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\gzip.py:58, in open(filename, mode, compresslevel, encoding, errors, newline)
#      56 gz_mode = mode.replace("t", "")
#      57 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58     binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59 elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60     binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ...

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.precision', 2)
pd.set_option('display.expand_frame_repr', False)


# Загрузка данных из NumPy массива
dir = 'I:\\Traider_bot\\обработка данных\\parsing\\data\\'
name = 'block_data_741801-741850.parquet'
data = pd.read_parquet(dir+name)

# Преобразование NumPy массива в DataFrame
df = pd.DataFrame(data)

# Вывод первых нескольких строк DataFrame для проверки
pd.set_option('display.max_colwidth', None)
# print(df.loc[df['Amount']]>0)
print(df.sample(10))
# Out:
#                                                           Transaction_id                                   Wallet_id  Btc_block_time_price  Block_time  Block_height                                                        Block_hash   n       Amount  Transactions_Count
# 275845  a2af926e617123272a13e546fb7534f2e9f1c4784060983a083060ad08917317          1EKYVRVcBtdaVrkEydM9mhbXCi5HxCmVzY              20387.41  1655890577        741837  00000000000000000009279b67ab6c3687b5907294f284bd366a822349c6627f   0   0.04883852                   1
# 385737  909d0e4d7f26982d8f8d0d637fc2e8fcf93dd4ee47775f95b307b05a465c4ff2          13QL9yKyPzoQiJszpxfxUDFgLJgzd1N8xg              20563.76  1655898098        741849  000000000000000000047a450a48cc4d34a4621c6f7d036ff085d4012905fc58  53  -0.01495940                   1
# ...

# %%
print(df.sample(10))
# Out:
#        index                                                    Transaction_id                                                       Wallet_id  Btc_block_time_price  Block_time  Block_height                                                        Block_hash      Amount
# 36034  22483  588504f1fa8a1b5c7810f244e15df9ed492165a348c1d76e7085c6de38a04f0c                      bc1qv03dzmj7aeyfdlg3gtdhjmdzzqlhxf7sfvjazy              23154.22  1658432890        745927  000000000000000000059378798f61509aee5f732f1d17604227ac2ab45689bf  0.00214899
# 34745  59235  be1bed5ee3746dcbccf460cbe665179839d2ced72b6520e6a962189d98021f49  bc1q9ms27gkmwennrhk34sufre4mv38gx8t3tfysqa9u8yuq7vedch6qjqvvuu              23154.22  1658432890        745927  000000000000000000059378798f61509aee5f732f1d17604227ac2ab45689bf  0.48847302
# ...

# %%
# ebb5013b65156d6684ee0be836308c2a3446cd9fa70820196bb3ce609274743e
df.loc[df.Amount < 0]
# Out:
#          index                                                    Transaction_id                                                       Wallet_id  Btc_block_time_price  Block_time  Block_height                                                        Block_hash       Amount
# 8334    132883  7b7b4d886c62522fa5c6ffe9300145a936f0e649fd1556d7df9c3cdd3fb15486                              32owsztmaRFw5UVJVdRrnEAebu5pMtD2xM              21261.61  1656134094        742231  00000000000000000000c55628e1b9684880fdcdb61c48e4900317cb2005c5b9  -0.00814536
# 8336    129402  777929bdd21a42d81f12f499318bd88c3f10af784440fff7352e980cbb57c467                      bc1q4p67rrh6gqyrdq9qmatrh8vkwaeurv74ufllpx              21261.61  1656134094        742231  00000000000000000000c55628e1b9684880fdcdb61c48e4900317cb2005c5b9  -0.15020902
# ...
